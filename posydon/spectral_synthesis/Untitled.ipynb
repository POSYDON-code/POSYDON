# %%
import sys
sys.version
import sys
import posydon
import os
import numpy as np
import astropy.constants as con
import astropy.units as unt
import matplotlib.pyplot as plt
import h5py
from astropy.io import fits
import pandas as pd
import math

# %%
oneline10 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_time_10.h5", key='oneline')
history10 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_time_10.h5", key='history')
last_binary_line10 = history10[history10.event == 'END']

# %%
last_binary_line10
# Out:
#                  state event        time   separation  orbital_period  \
# binary_index
# 0               merged   END         NaN          NaN             NaN
# 1             detached   END  10000000.0  2804.258991     5182.160105
# 2             detached   END  10000000.0    21.520174        3.166529
# 3             detached   END  10000000.0    95.910363       16.801973
# 4             detached   END  10000000.0    89.422572       10.034296
# ...                ...   ...         ...          ...             ...
# 99995         detached   END  10000000.0    82.502545       16.391969
# 99996         detached   END  10000000.0    16.800645        1.434444
# 99997         detached   END  10000000.0   201.152871       54.702104
# 99998         detached   END  10000000.0  2260.695983     3173.256110
# 99999         detached   END  10000000.0    18.368854        1.960134
#
#               eccentricity  rl_relative_overflow_1  rl_relative_overflow_2  \
# binary_index
# ...

# %%
oneline15 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_15.h5", key='oneline')
history15 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_15.h5", key='history')
last_binary_line15 = history15[history15.event == 'END']

# %%
oneline25 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_15.h5", key='oneline')
history25 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_15.h5", key='history')
last_binary_line25 = history25[history25.event == 'END']

# %%
oneline30 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_30.h5", key='oneline')
history30 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_30.h5", key='history')
last_binary_line30 = history30[history30.event == 'END']

# %%
oneline35 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_35.h5", key='oneline')
history35 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_35.h5", key='history')
last_binary_line35 = history35[history35.event == 'END']

# %%
oneline45 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_35.h5", key='oneline')
history45 = pd.read_hdf("/home/eirinikd/POSYDON_data/my_data/population_steps_time_35.h5", key='history')
last_binary_line45 = history45[history45.event == 'END']
